# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('data/PCTOT_04-14-2023_16-56-05-36_timeSeries.csv')

# %%
data.shape
# Out:
# (4320, 587)

# %%
data
# Out:
#             Country Name  Country Code
# 0                 Greece           174  \
# 1                 Greece           174
# 2                 Greece           174
# 3                 Greece           174
# 4                 Greece           174
# ...                  ...           ...
# 4315  Yemen, Republic of           474
# 4316  Yemen, Republic of           474
# 4317  Yemen, Republic of           474
# 4318        South Africa           199
# 4319        South Africa           199
#
#                                          Indicator Name Indicator Code
# 0     Commodity Import Price Index, Individual Commo...              m  \
# 1     Commodity Net Export Price Index, Individual C...             xm
# 2     Commodity Export Price Index, Individual Commo...          x_gdp
# 3     Commodity Import Price Index, Individual Commo...          m_gdp
# 4     Commodity Net Export Price Index, Individual C...         xm_gdp
# ...

# %%
vietnam = data[data['Country Name'] == 'Philippines']

# %%
vietnam
# Out:
#     Country Name  Country Code
# 28   Philippines           566  \
# 63   Philippines           566
# 89   Philippines           566
# 124  Philippines           566
# 150  Philippines           566
# 186  Philippines           566
# 238  Philippines           566
#
#                                         Indicator Name     Indicator Code
# 28     Consumer Prices, period average, percent change           PCPI_PCH  \
# 63      Consumer Prices, end of period, percent change          PCPIE_PCH
# 89   Gross domestic product, constant prices, Natio...          NGDP_RPCH
# 124                                  Unemployment rate                LUR
# 150  Gross domestic product, constant prices, purch...  NGDP_R_PPP_PC_PCH
# 186  Balance of Payments, Current Account, Total, N...        BCA_GDP_BP6
# 238  General government net lending/borrowing, perc...         GGXCNL_GDP
#
#     Attribute       1990       1991      1992      1993       1994  ...
# ...

# %%
countries = data['Country Name'].unique()

print(len(countries))
countries
# Out:
# 180
# array(['Greece', 'Grenada', 'Guatemala', 'Guyana',
#        'China, P.R.: Hong Kong', 'Honduras', 'Croatia', 'Haiti',
#        'Hungary', 'Bahamas, The', 'Bosnia and Herzegovina', 'Belarus',
#        'Belize', 'Bolivia', 'Brazil', 'Barbados', 'Indonesia', 'India',
#        'Ireland', 'Iran, Islamic Republic of', 'Iraq',
#        'Brunei Darussalam', 'Bhutan', 'Botswana',
#        'Central African Republic', 'Iceland', 'Israel', 'Canada',
#        'Switzerland', 'Chile', 'China, P.R.: Mainland', "Côte d'Ivoire",
#        'Guinea-Bissau', 'Bahrain, Kingdom of', 'Ecuador', 'Egypt',
#        'Cameroon', 'Congo, Democratic Republic of', 'Congo, Republic of',
#        'Colombia', 'Comoros', 'Djibouti', 'Dominica', 'Denmark',
#        'Dominican Republic', 'Algeria', 'Kenya', 'Kyrgyz Republic',
#        'Cambodia', 'Kiribati', 'St. Kitts and Nevis',
#        'Korea, Republic of', 'Kuwait', "Lao People's Democratic Republic",
# ...

# %%
indicator = data['Indicator Name'].unique()

print(len(indicator))
indicator
# Out:
# 6
# array(['Commodity Import Price Index, Individual Commodites Weighted by Ratio of Imports to Total Commodity Imports',
#        'Commodity Net Export Price Index, Individual Commodities Weighted by Ratio of Net Exports to Total Commodity Trade',
#        'Commodity Export Price Index, Individual Commodites Weighted by Ratio of Exports to GDP',
#        'Commodity Import Price Index, Individual Commodites Weighted by Ratio of Imports to GDP',
#        'Commodity Net Export Price Index, Individual Commodities Weighted by Ratio of Net Exports to GDP',
#        'Commodity Export Price Index, Individual Commodites Weighted by Ratio of Exports to Total Commodity Exports'],
#       dtype=object)

# %%
import xlrd

# Open the Excel file
workbook = xlrd.open_workbook('data/WEOApr2023all.xls')

# Read a specific sheet from the workbook
sheet = workbook.sheet_by_index(0)

# Iterate over rows and columns to access the data
for row in range(sheet.nrows):
    for col in range(sheet.ncols):
        cell_value = sheet.cell_value(row, col)
        print(cell_value)
# Out:
# ---------------------------------------------------------------------------
# XLRDError                                 Traceback (most recent call last)
# Cell In[44], line 4
#       1 import xlrd
#       3 # Open the Excel file
# ----> 4 workbook = xlrd.open_workbook('data/WEOApr2023all.xls')
#       6 # Read a specific sheet from the workbook
#       7 sheet = workbook.sheet_by_index(0)
#
# File ~/anaconda3/envs/data-analysis/lib/python3.8/site-packages/xlrd/__init__.py:172, in open_workbook(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows, ignore_workbook_corruption)
#     169 if file_format and file_format != 'xls':
#     170     raise XLRDError(FILE_FORMAT_DESCRIPTIONS[file_format]+'; not supported')
# --> 172 bk = open_workbook_xls(
#     173     filename=filename,
#     174     logfile=logfile,
#     175     verbosity=verbosity,
#     176     use_mmap=use_mmap,
#     177     file_contents=file_contents,
# ...

# %%
mif_coutries = pd.read_excel('data/WEOApr2023all.xls', engine='openpyxl')
# Out:
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 mif_coutries = pd.read_excel('data/WEOApr2023all.xls', engine='openpyxl')
#
# File ~/anaconda3/envs/data-analysis/lib/python3.8/site-packages/pandas/io/excel/_base.py:478, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend)
#     476 if not isinstance(io, ExcelFile):
#     477     should_close = True
# --> 478     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     479 elif engine and engine != io.engine:
#     480     raise ValueError(
#     481         "Engine should not be specified when passing "
# ...

# %%
import pymongo

# %%
# Connect to MongoDB

client = pymongo.MongoClient("mongodb://localhost:27017")
db = client['bank']
collection = db['customers']

# %%
# Query the database and retriver the data

data = collection.find()

# %%
# Convert a MongoDB Cursor to Panda DataFrame

df = pd.DataFrame(list(data))

# %%
df.head()
# Out:
#                         _id  age           job   marital          education
# 0  646315439d25d2fa22c642ef   49   blue-collar   married           basic.9y  \
# 1  646315439d25d2fa22c642f0   37  entrepreneur   married  university.degree
# 2  646315439d25d2fa22c642f1   78       retired   married           basic.4y
# 3  646315439d25d2fa22c642f2   36        admin.   married  university.degree
# 4  646315439d25d2fa22c642f3   59       retired  divorced  university.degree
#
#    default housing loan    contact month day_of_week  duration  campaign
# 0  unknown      no   no   cellular   nov         wed       227         4  \
# 1       no      no   no  telephone   nov         wed       202         2
# 2       no      no   no   cellular   jul         mon      1148         1
# 3       no     yes   no  telephone   may         mon       120         2
# 4       no      no   no   cellular   jun         tue       368         2
#
#    pdays  previous     poutcome    y
# ...
